# %% [markdown]
# Implement all Prompt Engineering approaches- Interview Approach, COT, TOT. Compare
# and contrast all and analyse their applications.  Implement Zero shot and Few shot
# prompting and compare their results.

# %%
from transformers import pipeline

# %%
qa_pipeline = pipeline("text-generation", model="gpt2")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu

# %%
#Interview Approach
def interview_approach(question):
    return qa_pipeline(question)[0]['generated_text']

# %%
#Chain of Thought
def cot_prompting(question):
    prompt = f"Q: {question}\nLet's break it down step by step to find the answer."
    return qa_pipeline(prompt)[0]['generated_text']

# %%
#Tree of Thought
def tot_prompting(question):
    prompt = f"Q: {question}\nLet's consider multiple possible solutions and evaluate the best one."
    return qa_pipeline(prompt)[0]['generated_text']

# %%
#Zero-Shot vs. Few-Shot Prompting
def zero_shot(question):
    return qa_pipeline(question)[0]['generated_text']

# %%
def few_shot(question):
    examples = "Q: What is 12 + 15? A: 27\nQ: What is 8 * 3? A: 24\n"
    return qa_pipeline(examples + f"Q: {question}\nA:")[0]['generated_text']

# %%
test_question = "What is 25 + 37?"

# Running all approaches
print("Interview Approach:", interview_approach(test_question))
print("Chain of Thought:", cot_prompting(test_question))
print("Tree of Thought:", tot_prompting(test_question))
print("Zero-Shot:", zero_shot(test_question))
print("Few-Shot:", few_shot(test_question))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Interview Approach: What is 25 + 37?
#
# A more accurate answer is to ask if you would have had a 100% positive experience with the game (or that much of it), or if you felt that you did a slightly better job of handling the game
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Chain of Thought: Q: What is 25 + 37?
# Let's break it down step by step to find the answer.
# We can use the numbers from the last point for every number. Just use the function number.find - which returns us our first one
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Tree of Thought: Q: What is 25 + 37?
# Let's consider multiple possible solutions and evaluate the best one. This is what is meant by the question: "How many ways do you get from 35 to 27?", which is what you asked. You can
# ...
